# %%
import pandas as pd
import time
import re
import os
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

# ✅ 로그인 쿠키 주입 함수
def set_cookies(driver, cookies):
    for cookie in cookies:
        driver.add_cookie(cookie)

# ✅ 작가 홈 방문 후 작품 수 크롤링
def get_total_works(driver, author_url):
    driver.get(author_url)
    time.sleep(1)
    if "community/u/" in author_url:
        try:
            work_elements = driver.find_elements(By.CSS_SELECTOR, 'li._1w7ywmw0')
            return len(work_elements)
        except Exception as e:
            print(f"작가 홈 크롤링 오류: {e}")
            return 0
    elif "artistTitle" in author_url:
        try:
            total_text = driver.find_element(By.CSS_SELECTOR, 'span.ComponentHead__count--bRLNZ').text.strip()
            work_count = int(re.search(r'\d+', total_text).group())
            return work_count
        except Exception as e:
            print(f"artistTitle 페이지 크롤링 오류: {e}")
            return 0
    else:
        print("알 수 없는 작가 페이지 형태")
        return 0

# ✅ 작품 페이지에서 작가 정보 및 작품 수 크롤링
def crawl_author_works(title_id, webtoon_url, driver):
    driver.get(webtoon_url)
    time.sleep(1)

    # 🚀 쿠키를 세션에 주입하고 refresh
    driver.refresh()
    time.sleep(1)

    # ✅ 각 변수 초기화
    writer_works = 0
    illustrator_works = 0
    writer_illustrator_works = 0
    original_writer_works = 0
    total_works = 0
    is_original_exist = 0

    # ✅ 작가 영역 개수만큼 루프 돌리기
    author_blocks = driver.find_elements(By.CSS_SELECTOR, 'span.ContentMetaInfo__category--WwrCp')
    for i in range(len(author_blocks)):
        try:
            # 🚀 반드시 fresh 요소를 다시 가져오기
            author_blocks = driver.find_elements(By.CSS_SELECTOR, 'span.ContentMetaInfo__category--WwrCp')
            block = author_blocks[i]

            role_text = block.text.strip()
            author_name = block.find_element(By.CSS_SELECTOR, 'a').text.strip()
            author_link = block.find_element(By.CSS_SELECTOR, 'a').get_attribute("href")
            print(f"[{title_id}] {role_text} | {author_name} | {author_link}")

            works_count = get_total_works(driver, author_link)

            if "글/그림" in role_text:
                writer_illustrator_works = works_count
            elif "글" in role_text:
                writer_works = works_count
            elif "그림" in role_text:
                illustrator_works = works_count
            elif "원작" in role_text:
                original_writer_works = works_count
                is_original_exist = 1

            total_works += works_count

        except Exception as e:
            print(f"작가 정보 수집 오류: {e}")
            continue

    # ✅ 결과 출력
    print(f"✅ [title_id: {title_id}] 글: {writer_works}, 그림: {illustrator_works}, 글/그림: {writer_illustrator_works}, 원작: {original_writer_works}, 총합: {total_works}, 원작여부: {is_original_exist}")

    return {
        'title_id': title_id,
        'writer_works': writer_works,
        'illustrator_works': illustrator_works,
        'writer_illustrator_works': writer_illustrator_works,
        'original_writer_works': original_writer_works,
        'total_works': total_works,
        'is_original': is_original_exist
    }

# ✅ 🔥 크롤링 실행부
if __name__ == "__main__":
    # 🔥 로그인 쿠키 준비
    cookies = [
        {"name": "NID_AUT", "value": "kY4ygf1UDrtliANsS5KDqCPwtEfDHpwGd9zwoYYhifJUl0bwDDDggqXtfCxU/Urv", "domain": ".naver.com"},
        {"name": "NID_SES", "value": "...", "domain": ".naver.com"}
    ]

    # 🔥 CSV 읽기
    df = pd.read_csv('naver_작가 작품 수, 원작 여부 병합 전_only19.csv', encoding='utf-8')

    # 🔥 결과 저장용
    results = []

    # 🔥 폴더 생성
    folder_name = "19세_작가_작품수_결과"
    os.makedirs(folder_name, exist_ok=True)

    # 🔥 Selenium driver 실행
    chrome_options = Options()
    chrome_options.add_argument("--headless=new")
    driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)

    # ✅ 쿠키 주입
    driver.get("https://comic.naver.com/")
    time.sleep(1)
    set_cookies(driver, cookies)
    driver.refresh()
    time.sleep(1)

    # ✅ 각 작품별 크롤링
    for idx, row in df.iterrows():
        title_id = row['title_id']
        webtoon_url = f"https://comic.naver.com/webtoon/list?titleId={title_id}"
        result = crawl_author_works(title_id, webtoon_url, driver)
        results.append(result)

    driver.quit()

    # 🔥 결과 CSV 저장
    df_result = pd.DataFrame(results)
    result_file = os.path.join(folder_name, "19세_작가_작품수_최종.csv")
    df_result.to_csv(result_file, index=False, encoding='utf-8-sig')
    print(f"🎉 최종 결과 저장 완료: {result_file}")
# Out:
# [697654] 황준호
# ∙
# 글/그림 | 황준호 | https://comic.naver.com/community/u/hwangjunho?lastPage=EpisodeList
# ✅ [title_id: 697654] 글: 0, 그림: 0, 글/그림: 10, 원작: 0, 총합: 10, 원작여부: 0
# [628997] 김칸비
# ∙
# 글 | 김칸비 | https://comic.naver.com/community/u/carnbykim?lastPage=EpisodeList
# 작가 정보 수집 오류: list index out of range
# ✅ [title_id: 628997] 글: 9, 그림: 0, 글/그림: 0, 원작: 0, 총합: 9, 원작여부: 0
# [700858] 팀 겟네임
# ∙
# 글 | 팀 겟네임 | https://comic.naver.com/artistTitle?id=103
# [700858] 그림
# 설레임 | 설레임 | https://comic.naver.com/artistTitle?id=312439
# [700858] 글
# 팀 겟네임
# ∙
# 아루아니 | 팀 겟네임 | https://comic.naver.com/artistTitle?id=103
# ✅ [title_id: 700858] 글: 5, 그림: 2, 글/그림: 0, 원작: 0, 총합: 12, 원작여부: 0
# [821589] 지공
# ∙
# 글/그림 | 지공 | https://comic.naver.com/community/u/_jbwx9?lastPage=EpisodeList
# ✅ [title_id: 821589] 글: 0, 그림: 0, 글/그림: 2, 원작: 0, 총합: 2, 원작여부: 0
# [703851] 공현곤
# ∙
# 글/그림 | 공현곤 | https://comic.naver.com/community/u/konggon?lastPage=EpisodeList
# ✅ [title_id: 703851] 글: 0, 그림: 0, 글/그림: 6, 원작: 0, 총합: 6, 원작여부: 0
# [696617] 연제원
# ∙
# 글/그림 | 연제원 | https://comic.naver.com/community/u/YJW?lastPage=EpisodeList
# ✅ [title_id: 696617] 글: 0, 그림: 0, 글/그림: 8, 원작: 0, 총합: 8, 원작여부: 0
# [773522] 김계란
# ∙
# 글/그림 | 김계란 | https://comic.naver.com/community/u/kimstep?lastPage=EpisodeList
# ✅ [title_id: 773522] 글: 0, 그림: 0, 글/그림: 4, 원작: 0, 총합: 4, 원작여부: 0
# [660366] 매미
# ∙
# 글 | 매미 | https://comic.naver.com/artistTitle?id=292087
# [660366] 그림
# 희세 | 희세 | https://comic.naver.com/artistTitle?id=292088
# ✅ [title_id: 660366] 글: 3, 그림: 3, 글/그림: 0, 원작: 0, 총합: 6, 원작여부: 0
# [805745] d몬
# ∙
# 글/그림 | d몬 | https://comic.naver.com/artistTitle?id=333167
# ✅ [title_id: 805745] 글: 0, 그림: 0, 글/그림: 6, 원작: 0, 총합: 6, 원작여부: 0
# [805746] d몬
# ∙
# 글/그림 | d몬 | https://comic.naver.com/artistTitle?id=333167
# ✅ [title_id: 805746] 글: 0, 그림: 0, 글/그림: 6, 원작: 0, 총합: 6, 원작여부: 0
# [807859] 이작가야
# ∙
# 글/그림 | 이작가야 | https://comic.naver.com/community/u/ddongjooya?lastPage=EpisodeList
# ✅ [title_id: 807859] 글: 0, 그림: 0, 글/그림: 1, 원작: 0, 총합: 1, 원작여부: 0
# [797410] 이연
# ∙
# 글 | 이연 | https://comic.naver.com/community/u/lyyonevv?lastPage=EpisodeList
# 작가 정보 수집 오류: list index out of range
# 작가 정보 수집 오류: list index out of range
# ✅ [title_id: 797410] 글: 4, 그림: 0, 글/그림: 0, 원작: 0, 총합: 4, 원작여부: 0
# [656641] 아루아니
# ∙
# 글/그림 | 아루아니 | https://comic.naver.com/community/u/_1boqn?lastPage=EpisodeList
# 작가 정보 수집 오류: list index out of range
# ✅ [title_id: 656641] 글: 0, 그림: 0, 글/그림: 4, 원작: 0, 총합: 4, 원작여부: 0
# [696593] DEY
# ∙
# 글/그림 | DEY | https://comic.naver.com/artistTitle?id=277700
# ✅ [title_id: 696593] 글: 0, 그림: 0, 글/그림: 3, 원작: 0, 총합: 3, 원작여부: 0
# [675823] 이강
# ∙
# 글/그림 | 이강 | https://comic.naver.com/community/u/_9boqw?lastPage=EpisodeList
# ✅ [title_id: 675823] 글: 0, 그림: 0, 글/그림: 2, 원작: 0, 총합: 2, 원작여부: 0
# [730259] 하일권
# ∙
# 글/그림 | 하일권 | https://comic.naver.com/community/u/Hailkwon?lastPage=EpisodeList
# ✅ [title_id: 730259] 글: 0, 그림: 0, 글/그림: 15, 원작: 0, 총합: 15, 원작여부: 0
# [812414] 로즈옹
# ∙
# 글/그림 | 로즈옹 | https://comic.naver.com/artistTitle?id=368158
# ✅ [title_id: 812414] 글: 0, 그림: 0, 글/그림: 1, 원작: 0, 총합: 1, 원작여부: 0
# [674209] 하일권
# ∙
# 글/그림 | 하일권 | https://comic.naver.com/community/u/Hailkwon?lastPage=EpisodeList
# ✅ [title_id: 674209] 글: 0, 그림: 0, 글/그림: 15, 원작: 0, 총합: 15, 원작여부: 0
# [423392] 모래인간
# ∙
# 글/그림 | 모래인간 | https://comic.naver.com/artistTitle?id=225703
# ✅ [title_id: 423392] 글: 0, 그림: 0, 글/그림: 3, 원작: 0, 총합: 3, 원작여부: 0
# [802293] 민송아
# ∙
# 글/그림 | 민송아 | https://comic.naver.com/community/u/_3i1sk?lastPage=EpisodeList
# ✅ [title_id: 802293] 글: 0, 그림: 0, 글/그림: 3, 원작: 0, 총합: 3, 원작여부: 0
# [520600] 신의철
# ∙
# 글 | 신의철 | https://comic.naver.com/community/u/iron?lastPage=EpisodeList
# 작가 정보 수집 오류: list index out of range
# ✅ [title_id: 520600] 글: 18, 그림: 0, 글/그림: 0, 원작: 0, 총합: 18, 원작여부: 0
# [682265] 꼬마비
# ∙
# 글/그림 | 꼬마비 | https://comic.naver.com/artistTitle?id=268742
# ✅ [title_id: 682265] 글: 0, 그림: 0, 글/그림: 9, 원작: 0, 총합: 9, 원작여부: 0
# [775723] 하일권
# ∙
# 글/그림 | 하일권 | https://comic.naver.com/community/u/Hailkwon?lastPage=EpisodeList
# ✅ [title_id: 775723] 글: 0, 그림: 0, 글/그림: 15, 원작: 0, 총합: 15, 원작여부: 0
# [818781] 가재
# ∙
# 글 | 가재 | https://comic.naver.com/artistTitle?id=373154
# [818781] 그림
# 도달 | 도달 | https://comic.naver.com/artistTitle?id=355270
# ✅ [title_id: 818781] 글: 1, 그림: 3, 글/그림: 0, 원작: 0, 총합: 4, 원작여부: 0
# [776306] 은성
# ∙
# 글 | 은성 | https://comic.naver.com/community/u/_wbowr?lastPage=EpisodeList
# 작가 정보 수집 오류: list index out of range
# ✅ [title_id: 776306] 글: 4, 그림: 0, 글/그림: 0, 원작: 0, 총합: 4, 원작여부: 0
# [822835] 네온비
# ∙
# 글/그림 | 네온비 | https://comic.naver.com/artistTitle?id=277378
# ✅ [title_id: 822835] 글: 0, 그림: 0, 글/그림: 4, 원작: 0, 총합: 4, 원작여부: 0
# [742826] 김숭늉
# ∙
# 글/그림 | 김숭늉 | https://comic.naver.com/community/u/_1bovi?lastPage=EpisodeList
# ✅ [title_id: 742826] 글: 0, 그림: 0, 글/그림: 6, 원작: 0, 총합: 6, 원작여부: 0
# [822640] 은하이
# ∙
# 글/그림 | 은하이 | https://comic.naver.com/community/u/_uxi7a?lastPage=EpisodeList
# ✅ [title_id: 822640] 글: 0, 그림: 0, 글/그림: 2, 원작: 0, 총합: 2, 원작여부: 0
# [818791] 신송림
# ∙
# 글/그림 | 신송림 | https://comic.naver.com/artistTitle?id=373166
# ✅ [title_id: 818791] 글: 0, 그림: 0, 글/그림: 1, 원작: 0, 총합: 1, 원작여부: 0
# [804318] 고요빛
# ∙
# 글 | 고요빛 | https://comic.naver.com/community/u/goyobit?lastPage=EpisodeList
# 작가 정보 수집 오류: list index out of range
# ✅ [title_id: 804318] 글: 6, 그림: 0, 글/그림: 0, 원작: 0, 총합: 6, 원작여부: 0
# [707671] 한(恨)
# ∙
# 글/그림 | 한(恨) | https://comic.naver.com/artistTitle?id=95
# ✅ [title_id: 707671] 글: 0, 그림: 0, 글/그림: 7, 원작: 0, 총합: 7, 원작여부: 0
# [608259] 임진국
# ∙
# 글/그림 | 임진국 | https://comic.naver.com/community/u/realsoup?lastPage=EpisodeList
# ✅ [title_id: 608259] 글: 0, 그림: 0, 글/그림: 7, 원작: 0, 총합: 7, 원작여부: 0
# [805730] 후
# ∙
# 글/그림 | 후 | https://comic.naver.com/community/u/_ebowx?lastPage=EpisodeList
# ✅ [title_id: 805730] 글: 0, 그림: 0, 글/그림: 2, 원작: 0, 총합: 2, 원작여부: 0
# [89098] 단우
# ∙
# 글/그림 | 단우 | https://comic.naver.com/artistTitle?id=61
# ✅ [title_id: 89098] 글: 0, 그림: 0, 글/그림: 5, 원작: 0, 총합: 5, 원작여부: 0
# [675393] 미티
# ∙
# 글 | 미티 | https://comic.naver.com/community/u/_lboop?lastPage=EpisodeList
# 작가 정보 수집 오류: list index out of range
# ✅ [title_id: 675393] 글: 24, 그림: 0, 글/그림: 0, 원작: 0, 총합: 24, 원작여부: 0
# [783057] 다쓴총
# ∙
# 글/그림 | 다쓴총 | https://comic.naver.com/artistTitle?id=351032
# ✅ [title_id: 783057] 글: 0, 그림: 0, 글/그림: 1, 원작: 0, 총합: 1, 원작여부: 0
# [812161] 황준호
# ∙
# 글/그림 | 황준호 | https://comic.naver.com/community/u/hwangjunho?lastPage=EpisodeList
# ✅ [title_id: 812161] 글: 0, 그림: 0, 글/그림: 10, 원작: 0, 총합: 10, 원작여부: 0
# [94760] 황준호
# ∙
# 글/그림 | 황준호 | https://comic.naver.com/community/u/hwangjunho?lastPage=EpisodeList
# ✅ [title_id: 94760] 글: 0, 그림: 0, 글/그림: 10, 원작: 0, 총합: 10, 원작여부: 0
# [756139] 이강
# ∙
# 글/그림 | 이강 | https://comic.naver.com/community/u/_9boqw?lastPage=EpisodeList
# ✅ [title_id: 756139] 글: 0, 그림: 0, 글/그림: 2, 원작: 0, 총합: 2, 원작여부: 0
# [258205] 태발
# ∙
# 글/그림 | 태발 | https://comic.naver.com/community/u/TAEBAL?lastPage=EpisodeList
# ✅ [title_id: 258205] 글: 0, 그림: 0, 글/그림: 10, 원작: 0, 총합: 10, 원작여부: 0
# [658823] 이현세
# ∙
# 글/그림 | 이현세 | https://comic.naver.com/artistTitle?id=291398
# ✅ [title_id: 658823] 글: 0, 그림: 0, 글/그림: 4, 원작: 0, 총합: 4, 원작여부: 0
# [137706] 김우준
# ∙
# 글/그림 | 김우준 | https://comic.naver.com/community/u/JJooon?lastPage=EpisodeList
# ✅ [title_id: 137706] 글: 0, 그림: 0, 글/그림: 7, 원작: 0, 총합: 7, 원작여부: 0
# [837279] 뉸
# ∙
# 글/그림 | 뉸 | https://comic.naver.com/community/u/nyun?lastPage=EpisodeList
# ✅ [title_id: 837279] 글: 0, 그림: 0, 글/그림: 4, 원작: 0, 총합: 4, 원작여부: 0
# [829780] 루즌아
# ∙
# 글/그림 | 루즌아 | https://comic.naver.com/community/u/rusena?lastPage=EpisodeList
# ✅ [title_id: 829780] 글: 0, 그림: 0, 글/그림: 9, 원작: 0, 총합: 9, 원작여부: 0
# [661043] 한(恨)
# ∙
# 글/그림 | 한(恨) | https://comic.naver.com/artistTitle?id=95
# ✅ [title_id: 661043] 글: 0, 그림: 0, 글/그림: 7, 원작: 0, 총합: 7, 원작여부: 0
# [509093] 동비
# ∙
# 글/그림 | 동비 | https://comic.naver.com/artistTitle?id=240310
# ✅ [title_id: 509093] 글: 0, 그림: 0, 글/그림: 2, 원작: 0, 총합: 2, 원작여부: 0
# [789428] 희나리
# ∙
# 글/그림 | 희나리 | https://comic.naver.com/artistTitle?id=329941
# ✅ [title_id: 789428] 글: 0, 그림: 0, 글/그림: 7, 원작: 0, 총합: 7, 원작여부: 0
# [26115] 한(恨)
# ∙
# 글/그림 | 한(恨) | https://comic.naver.com/artistTitle?id=95
# ✅ [title_id: 26115] 글: 0, 그림: 0, 글/그림: 7, 원작: 0, 총합: 7, 원작여부: 0
# [804163] 552
# ∙
# 글/그림 | 552 | https://comic.naver.com/community/u/_qbp4o?lastPage=EpisodeList
# 작가 정보 수집 오류: list index out of range
# 작가 정보 수집 오류: list index out of range
# ✅ [title_id: 804163] 글: 0, 그림: 0, 글/그림: 1, 원작: 0, 총합: 1, 원작여부: 0
# [812152] 뉸
# ∙
# 글/그림 | 뉸 | https://comic.naver.com/community/u/nyun?lastPage=EpisodeList
# ✅ [title_id: 812152] 글: 0, 그림: 0, 글/그림: 4, 원작: 0, 총합: 4, 원작여부: 0
# [774762] DEY
# ∙
# 글/그림 | DEY | https://comic.naver.com/artistTitle?id=277700
# ✅ [title_id: 774762] 글: 0, 그림: 0, 글/그림: 3, 원작: 0, 총합: 3, 원작여부: 0
# [719508] 장성준
# ∙
# 글/그림 | 장성준 | https://comic.naver.com/artistTitle?id=321638
# ✅ [title_id: 719508] 글: 0, 그림: 0, 글/그림: 1, 원작: 0, 총합: 1, 원작여부: 0
# [400736] 태발
# ∙
# 글/그림 | 태발 | https://comic.naver.com/community/u/TAEBAL?lastPage=EpisodeList
# ✅ [title_id: 400736] 글: 0, 그림: 0, 글/그림: 10, 원작: 0, 총합: 10, 원작여부: 0
# [517773] 하일권
# ∙
# 글/그림 | 하일권 | https://comic.naver.com/community/u/Hailkwon?lastPage=EpisodeList
# ✅ [title_id: 517773] 글: 0, 그림: 0, 글/그림: 15, 원작: 0, 총합: 15, 원작여부: 0
# [747273] 공세리
# ∙
# 글 | 공세리 | https://comic.naver.com/artistTitle?id=336262
# [747273] 그림
# 영영이 | 영영이 | https://comic.naver.com/artistTitle?id=336263
# ✅ [title_id: 747273] 글: 1, 그림: 2, 글/그림: 0, 원작: 0, 총합: 3, 원작여부: 0
# [186813] 이승찬
# ∙
# 글/그림 | 이승찬 | https://comic.naver.com/artistTitle?id=156439
# ✅ [title_id: 186813] 글: 0, 그림: 0, 글/그림: 4, 원작: 0, 총합: 4, 원작여부: 0
# [816610] 팀 새풍
# ∙
# 글 | 팀 새풍 | https://comic.naver.com/artistTitle?id=371273
# [816610] 그림
# 팀 유삐빠 | 팀 유삐빠 | https://comic.naver.com/artistTitle?id=371274
# [816610] 원작
# 비향 | 비향 | https://comic.naver.com/artistTitle?id=371275
# ✅ [title_id: 816610] 글: 1, 그림: 1, 글/그림: 0, 원작: 1, 총합: 3, 원작여부: 1
# [773417] 신희빈
# ∙
# 글 | 신희빈 | https://comic.naver.com/community/u/_hboy7?lastPage=EpisodeList
# 작가 정보 수집 오류: list index out of range
# ✅ [title_id: 773417] 글: 2, 그림: 0, 글/그림: 0, 원작: 0, 총합: 2, 원작여부: 0
# [727784] 정찬
# ∙
# 글/그림 | 정찬 | https://comic.naver.com/artistTitle?id=325574
# ✅ [title_id: 727784] 글: 0, 그림: 0, 글/그림: 2, 원작: 0, 총합: 2, 원작여부: 0
# [811841] 연제원
# ∙
# 글/그림 | 연제원 | https://comic.naver.com/community/u/YJW?lastPage=EpisodeList
# ✅ [title_id: 811841] 글: 0, 그림: 0, 글/그림: 8, 원작: 0, 총합: 8, 원작여부: 0
# [729563] 247
# ∙
# 글/그림 | 247 | https://comic.naver.com/community/u/247?lastPage=EpisodeList
# ✅ [title_id: 729563] 글: 0, 그림: 0, 글/그림: 3, 원작: 0, 총합: 3, 원작여부: 0
# [793350] 이유정
# ∙
# 글/그림 | 이유정 | https://comic.naver.com/artistTitle?id=33
# ✅ [title_id: 793350] 글: 0, 그림: 0, 글/그림: 3, 원작: 0, 총합: 3, 원작여부: 0
# [819690] 김숭늉
# ∙
# 글/그림 | 김숭늉 | https://comic.naver.com/community/u/_1bovi?lastPage=EpisodeList
# ✅ [title_id: 819690] 글: 0, 그림: 0, 글/그림: 6, 원작: 0, 총합: 6, 원작여부: 0
# [791253] 루즌아
# ∙
# 글 | 루즌아 | https://comic.naver.com/community/u/rusena?lastPage=EpisodeList
# 작가 정보 수집 오류: list index out of range
# ✅ [title_id: 791253] 글: 9, 그림: 0, 글/그림: 0, 원작: 0, 총합: 9, 원작여부: 0
# [530312] 선정성
# ∙
# 글/그림 | 선정성 | https://comic.naver.com/artistTitle?id=245902
# ✅ [title_id: 530312] 글: 0, 그림: 0, 글/그림: 1, 원작: 0, 총합: 1, 원작여부: 0
# [726095] 령
# ∙
# 글/그림 | 령 | https://comic.naver.com/community/u/_bbq85?lastPage=EpisodeList
# ✅ [title_id: 726095] 글: 0, 그림: 0, 글/그림: 5, 원작: 0, 총합: 5, 원작여부: 0
# [745237] 아포리아
# ∙
# 글/그림 | 아포리아 | https://comic.naver.com/community/u/_norry?lastPage=EpisodeList
# ✅ [title_id: 745237] 글: 0, 그림: 0, 글/그림: 4, 원작: 0, 총합: 4, 원작여부: 0
# [67235] 주동근
# ∙
# 글/그림 | 주동근 | https://comic.naver.com/community/u/donggri?lastPage=EpisodeList
# ✅ [title_id: 67235] 글: 0, 그림: 0, 글/그림: 9, 원작: 0, 총합: 9, 원작여부: 0
# [819057] 망순
# ∙
# 글/그림 | 망순 | https://comic.naver.com/community/u/_dbovr?lastPage=EpisodeList
# ✅ [title_id: 819057] 글: 0, 그림: 0, 글/그림: 4, 원작: 0, 총합: 4, 원작여부: 0
# [801951] 김수현
# ∙
# 글/그림 | 김수현 | https://comic.naver.com/artistTitle?id=359123
# [801951] 원작
# 김서진 | 김서진 | https://comic.naver.com/artistTitle?id=359124
# ✅ [title_id: 801951] 글: 0, 그림: 0, 글/그림: 1, 원작: 1, 총합: 2, 원작여부: 1
# [801582] 욥
# ∙
# 글/그림 | 욥 | https://comic.naver.com/artistTitle?id=358963
# ✅ [title_id: 801582] 글: 0, 그림: 0, 글/그림: 1, 원작: 0, 총합: 1, 원작여부: 0
# [829528] 해영채
# ∙
# 글/그림 | 해영채 | https://comic.naver.com/community/u/H0c?lastPage=EpisodeList
# ✅ [title_id: 829528] 글: 0, 그림: 0, 글/그림: 4, 원작: 0, 총합: 4, 원작여부: 0
# [670143] 삭
# ∙
# 글/그림 | 삭 | https://comic.naver.com/community/u/SAKK?lastPage=EpisodeList
# ✅ [title_id: 670143] 글: 0, 그림: 0, 글/그림: 3, 원작: 0, 총합: 3, 원작여부: 0
# [679547] 윤인완
# ∙
# 글 | 윤인완 | https://comic.naver.com/artistTitle?id=183633
# [679547] 그림
# 양경일 | 양경일 | https://comic.naver.com/artistTitle?id=285222
# ✅ [title_id: 679547] 글: 9, 그림: 6, 글/그림: 0, 원작: 0, 총합: 15, 원작여부: 0
# [783055] 김꿀빨
# ∙
# 글/그림 | 김꿀빨 | https://comic.naver.com/artistTitle?id=357917
# [783055] 그림
# 김꿀빨 | 김꿀빨 | https://comic.naver.com/artistTitle?id=357917
# ✅ [title_id: 783055] 글: 0, 그림: 6, 글/그림: 6, 원작: 0, 총합: 12, 원작여부: 0
# [632341] 혀노
# ∙
# 글/그림 | 혀노 | https://comic.naver.com/community/u/_vokev?lastPage=EpisodeList
# ✅ [title_id: 632341] 글: 0, 그림: 0, 글/그림: 4, 원작: 0, 총합: 4, 원작여부: 0
# [812124] 김숭늉
# ∙
# 글/그림 | 김숭늉 | https://comic.naver.com/community/u/_1bovi?lastPage=EpisodeList
# 작가 정보 수집 오류: list index out of range
# ✅ [title_id: 812124] 글: 0, 그림: 0, 글/그림: 6, 원작: 0, 총합: 6, 원작여부: 0
# 🎉 최종 결과 저장 완료: 19세_작가_작품수_결과\19세_작가_작품수_최종.csv
